# %% [markdown]
# # Deep Learning: Segmentación de imágenes

# %% [markdown]
# Deep learning es un tipo de aprendizaje de máquinas en donde las predicciones se realizan a través de una serie de operaciones matriciales concatenadas. Uno de los elementos más importantes en el Deep Learning es la casi nula ingeniería de características. En el ejemplo que veremos ahora, se utiliza un conjunto de imágenes segmentadas para realizar el entrenamiento de un modelo de segmentación automática de núcleos celulares, este entrenamiento simplemente se realiza con los pixeles crudos de las imágenes, sin ingeniería de características.

# %%
# Importamos todos los paquetes y módulos para entrenar el modelo

import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

# %% [markdown]
# Google Colab nos ofrece poder utilizar GPUs (Graphical Processing Units) para realizar el entrenamiento. La utilización de este hardware nos facilita un entrenamiento muy significativamente más rápido que el entrenamiento en CPU.

# %%
tf.test.gpu_device_name() # Verificamos que Tensorflow está utilizando una GPU
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Clasificación Inception V3

# %%
#Descargamos la Base de Datos, una versión mini de ImageNet
# !gdown 1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc -O cats.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc
# From (redirected): https://drive.google.com/uc?id=1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc&confirm=t&uuid=8d1da506-0f2d-4d4c-b779-199610c22e6c
# To: /content/cats.zip
# 100% 129M/129M [00:02<00:00, 46.8MB/s]

# %%
#Unzip BD
# !unzip -q cats.zip -d cats/

# %%
from tensorflow.keras.applications import InceptionV3

#Base Model
pre_trained_model = InceptionV3(
    input_shape=(299, 299, 3), include_top=True, weights="imagenet")

#Base model por transfer
pre_trained_model_transfer = InceptionV3(
    input_shape=(224, 224, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from PIL import Image

img_size = (224, 224)

def plot_images(folder):
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir()]
    fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(12, 6))
    for i, subfolder in enumerate(subfolders):
        filenames = os.listdir(subfolder)
        image_path = os.path.join(subfolder, filenames[4])
        image = Image.open(image_path)
        imgae = image.resize(img_size)
        ax = axes[i // 5, i % 5]
        ax.imshow(image)
        ax.set_title(os.path.basename(subfolder))
        ax.axis("off")

plot_images("/content/cats/train")

# %%
#Cargar Cats
#Data Augmentation
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255) # A las imágenes se les normaliza el brillo

train_datagen_aug = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                                shear_range = 0.2, # Distorsionamos las imágenes
                                                                zoom_range = 0.2, # Acercamos las imágenes
                                                                horizontal_flip = True,
                                                                vertical_flip=True) # Volteamos horizontalmente las imágenes

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)

#Entrenamiento
train_cat = train_datagen.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Entrenamiento Data Augmentation
train_cat_aug = train_datagen_aug.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Validación
val_cat = test_datagen.flow_from_directory('/content/cats/valid',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Test
test_cat = test_datagen.flow_from_directory('/content/cats/test',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')
# Out:
# Found 2339 images belonging to 10 classes.
# Found 2339 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.

# %%
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
def get_callbacks(name_checkpoint='cats.hdf5.keras'):
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
    checkpoint = ModelCheckpoint(name_checkpoint,verbose=1, save_best_only= True)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
    return [reduce_lr, checkpoint, early_stop]

# %%
#Flatten a una capa de 1 dimensión
x = layers.Flatten()(pre_trained_model_transfer.output)
#Se añade una capa Fully-Connected
x = layers.Dense(1024, activation="relu")(x)
#Se añade una capa de Dropout
x = layers.Dropout(0.2)(x)
#Capa final de clasificación
x = layers.Dense(10, activation="softmax")(x)

# %%
model_1 = Model(pre_trained_model_transfer.input, x)

model_1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

hist_1 = model_1.fit(train_cat,
          epochs = 30,
          validation_data = val_cat,
          callbacks=get_callbacks(name_checkpoint='Model1cats.hdf5.keras'))
# Out:
# Epoch 1/30
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.3393 - loss: 0.2652
# Epoch 1: val_loss improved from inf to 16.40963, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 156s 614ms/step - accuracy: 0.3395 - loss: 0.2651 - val_accuracy: 0.1000 - val_loss: 16.4096 - learning_rate: 0.0010
# Epoch 2/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4775 - loss: 0.2241
# Epoch 2: val_loss did not improve from 16.40963
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.4776 - loss: 0.2241 - val_accuracy: 0.3200 - val_loss: 17.5356 - learning_rate: 0.0010
# Epoch 3/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5273 - loss: 0.2065
# Epoch 3: val_loss did not improve from 16.40963
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.5274 - loss: 0.2065 - val_accuracy: 0.1400 - val_loss: 174.5176 - learning_rate: 0.0010
# Epoch 4/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5713 - loss: 0.1882
# Epoch 4: val_loss improved from 16.40963 to 0.31983, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 50s 341ms/step - accuracy: 0.5714 - loss: 0.1881 - val_accuracy: 0.4800 - val_loss: 0.3198 - learning_rate: 0.0010
# Epoch 5/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6469 - loss: 0.1601
# Epoch 5: val_loss did not improve from 0.31983
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 21s 145ms/step - accuracy: 0.6469 - loss: 0.1601 - val_accuracy: 0.5000 - val_loss: 0.3633 - learning_rate: 0.0010
# Epoch 6/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6559 - loss: 0.1647
# Epoch 6: val_loss did not improve from 0.31983
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.6558 - loss: 0.1648 - val_accuracy: 0.2400 - val_loss: 2.2829 - learning_rate: 0.0010
# Epoch 7/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6866 - loss: 0.1544
# Epoch 7: val_loss improved from 0.31983 to 0.18162, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 45s 306ms/step - accuracy: 0.6865 - loss: 0.1544 - val_accuracy: 0.6200 - val_loss: 0.1816 - learning_rate: 0.0010
# Epoch 8/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6734 - loss: 0.1560
# Epoch 8: val_loss did not improve from 0.18162
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.6734 - loss: 0.1560 - val_accuracy: 0.4600 - val_loss: 0.2797 - learning_rate: 0.0010
# Epoch 9/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7181 - loss: 0.1360
# Epoch 9: val_loss did not improve from 0.18162
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.7181 - loss: 0.1360 - val_accuracy: 0.5600 - val_loss: 0.9295 - learning_rate: 0.0010
# Epoch 10/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7590 - loss: 0.1189
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 10: val_loss did not improve from 0.18162
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.7589 - loss: 0.1189 - val_accuracy: 0.3600 - val_loss: 0.4318 - learning_rate: 0.0010
# Epoch 11/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7624 - loss: 0.1182
# Epoch 11: val_loss improved from 0.18162 to 0.11262, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 59s 404ms/step - accuracy: 0.7627 - loss: 0.1180 - val_accuracy: 0.7800 - val_loss: 0.1126 - learning_rate: 1.0000e-04
# Epoch 12/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8464 - loss: 0.0810
# Epoch 12: val_loss improved from 0.11262 to 0.08312, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 45s 310ms/step - accuracy: 0.8465 - loss: 0.0809 - val_accuracy: 0.8600 - val_loss: 0.0831 - learning_rate: 1.0000e-04
# Epoch 13/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8748 - loss: 0.0683
# Epoch 13: val_loss improved from 0.08312 to 0.07974, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 86s 338ms/step - accuracy: 0.8747 - loss: 0.0683 - val_accuracy: 0.8200 - val_loss: 0.0797 - learning_rate: 1.0000e-04
# Epoch 14/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8692 - loss: 0.0685
# Epoch 14: val_loss did not improve from 0.07974
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.8692 - loss: 0.0685 - val_accuracy: 0.8400 - val_loss: 0.0934 - learning_rate: 1.0000e-04
# Epoch 15/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8914 - loss: 0.0603
# Epoch 15: val_loss improved from 0.07974 to 0.07793, saving model to Model1cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 60s 410ms/step - accuracy: 0.8914 - loss: 0.0603 - val_accuracy: 0.9000 - val_loss: 0.0779 - learning_rate: 1.0000e-04
# Epoch 16/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9050 - loss: 0.0533
# Epoch 16: val_loss did not improve from 0.07793
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9050 - loss: 0.0533 - val_accuracy: 0.8200 - val_loss: 0.0820 - learning_rate: 1.0000e-04
# Epoch 17/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9095 - loss: 0.0513
# Epoch 17: val_loss did not improve from 0.07793
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9095 - loss: 0.0513 - val_accuracy: 0.8400 - val_loss: 0.0937 - learning_rate: 1.0000e-04
# Epoch 18/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9149 - loss: 0.0458
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 18: val_loss did not improve from 0.07793
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 41s 148ms/step - accuracy: 0.9149 - loss: 0.0458 - val_accuracy: 0.7800 - val_loss: 0.1060 - learning_rate: 1.0000e-04
# Epoch 19/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9297 - loss: 0.0409
# Epoch 19: val_loss did not improve from 0.07793
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.9297 - loss: 0.0409 - val_accuracy: 0.8000 - val_loss: 0.1021 - learning_rate: 1.0000e-05
# Epoch 20/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9351 - loss: 0.0384
# Epoch 20: val_loss did not improve from 0.07793
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9351 - loss: 0.0384 - val_accuracy: 0.8000 - val_loss: 0.0972 - learning_rate: 1.0000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
# summarize history for accuracy
plt.plot(hist_1.history['accuracy'])
plt.plot(hist_1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist_1.history['loss'])
plt.plot(hist_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Actividad 1
#
# Entrene nuevamente el modelo Inception V3 utilizando aumento de datos y compruebe la diferencia en el entrenamiento.

# %%
#Prográmame
model_actividad_1 = Model(pre_trained_model_transfer.input, x)

model_actividad_1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

hist_actividad_1 = model_actividad_1.fit(train_cat_aug,
         epochs = 30,
         validation_data = val_cat,
         callbacks=get_callbacks())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.1074 - loss: 0.8318
# Epoch 1: val_loss improved from inf to 0.31696, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 169s 658ms/step - accuracy: 0.1075 - loss: 0.8294 - val_accuracy: 0.1600 - val_loss: 0.3170 - learning_rate: 0.0010
# Epoch 2/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.1553 - loss: 0.3272
# Epoch 2: val_loss did not improve from 0.31696
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 33s 226ms/step - accuracy: 0.1554 - loss: 0.3272 - val_accuracy: 0.1600 - val_loss: 0.5871 - learning_rate: 0.0010
# Epoch 3/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.1549 - loss: 0.3277
# Epoch 3: val_loss did not improve from 0.31696
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 232ms/step - accuracy: 0.1548 - loss: 0.3277 - val_accuracy: 0.1200 - val_loss: 0.8851 - learning_rate: 0.0010
# Epoch 4/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.1784 - loss: 0.3073
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 4: val_loss did not improve from 0.31696
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 232ms/step - accuracy: 0.1784 - loss: 0.3074 - val_accuracy: 0.1400 - val_loss: 1.9864 - learning_rate: 0.0010
# Epoch 5/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.2077 - loss: 0.2933
# Epoch 5: val_loss improved from 0.31696 to 0.31632, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 51s 349ms/step - accuracy: 0.2077 - loss: 0.2933 - val_accuracy: 0.2000 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 6/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.2032 - loss: 0.2870
# Epoch 6: val_loss improved from 0.31632 to 0.28580, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 46s 312ms/step - accuracy: 0.2032 - loss: 0.2870 - val_accuracy: 0.2400 - val_loss: 0.2858 - learning_rate: 1.0000e-04
# Epoch 7/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.2358 - loss: 0.2859
# Epoch 7: val_loss improved from 0.28580 to 0.27200, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 41s 279ms/step - accuracy: 0.2357 - loss: 0.2859 - val_accuracy: 0.2400 - val_loss: 0.2720 - learning_rate: 1.0000e-04
# Epoch 8/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.2349 - loss: 0.2853
# Epoch 8: val_loss did not improve from 0.27200
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 229ms/step - accuracy: 0.2350 - loss: 0.2853 - val_accuracy: 0.2800 - val_loss: 0.2775 - learning_rate: 1.0000e-04
# Epoch 9/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.2596 - loss: 0.2755
# Epoch 9: val_loss improved from 0.27200 to 0.26710, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 52s 353ms/step - accuracy: 0.2596 - loss: 0.2755 - val_accuracy: 0.3400 - val_loss: 0.2671 - learning_rate: 1.0000e-04
# Epoch 10/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.2454 - loss: 0.2778
# Epoch 10: val_loss improved from 0.26710 to 0.26563, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 47s 320ms/step - accuracy: 0.2456 - loss: 0.2778 - val_accuracy: 0.2800 - val_loss: 0.2656 - learning_rate: 1.0000e-04
# Epoch 11/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.3018 - loss: 0.2723
# Epoch 11: val_loss improved from 0.26563 to 0.25295, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 45s 302ms/step - accuracy: 0.3018 - loss: 0.2723 - val_accuracy: 0.3200 - val_loss: 0.2530 - learning_rate: 1.0000e-04
# Epoch 12/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.3026 - loss: 0.2615
# Epoch 12: val_loss did not improve from 0.25295
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 231ms/step - accuracy: 0.3027 - loss: 0.2615 - val_accuracy: 0.3400 - val_loss: 0.2641 - learning_rate: 1.0000e-04
# Epoch 13/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.3445 - loss: 0.2589
# Epoch 13: val_loss improved from 0.25295 to 0.24970, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 56s 382ms/step - accuracy: 0.3444 - loss: 0.2589 - val_accuracy: 0.2800 - val_loss: 0.2497 - learning_rate: 1.0000e-04
# Epoch 14/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.3549 - loss: 0.2492
# Epoch 14: val_loss improved from 0.24970 to 0.23829, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 56s 378ms/step - accuracy: 0.3548 - loss: 0.2492 - val_accuracy: 0.4200 - val_loss: 0.2383 - learning_rate: 1.0000e-04
# Epoch 15/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.3555 - loss: 0.2538
# Epoch 15: val_loss improved from 0.23829 to 0.22262, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 59s 400ms/step - accuracy: 0.3556 - loss: 0.2538 - val_accuracy: 0.3800 - val_loss: 0.2226 - learning_rate: 1.0000e-04
# Epoch 16/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.3695 - loss: 0.2425
# Epoch 16: val_loss improved from 0.22262 to 0.21612, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 48s 327ms/step - accuracy: 0.3696 - loss: 0.2425 - val_accuracy: 0.4600 - val_loss: 0.2161 - learning_rate: 1.0000e-04
# Epoch 17/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.4124 - loss: 0.2315
# Epoch 17: val_loss improved from 0.21612 to 0.21118, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 44s 300ms/step - accuracy: 0.4123 - loss: 0.2315 - val_accuracy: 0.4800 - val_loss: 0.2112 - learning_rate: 1.0000e-04
# Epoch 18/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.4153 - loss: 0.2306
# Epoch 18: val_loss did not improve from 0.21118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 33s 225ms/step - accuracy: 0.4154 - loss: 0.2306 - val_accuracy: 0.4000 - val_loss: 0.2113 - learning_rate: 1.0000e-04
# Epoch 19/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.4701 - loss: 0.2181
# Epoch 19: val_loss did not improve from 0.21118
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 230ms/step - accuracy: 0.4700 - loss: 0.2181 - val_accuracy: 0.4200 - val_loss: 0.2155 - learning_rate: 1.0000e-04
# Epoch 20/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.4630 - loss: 0.2154
# Epoch 20: val_loss improved from 0.21118 to 0.20499, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 56s 379ms/step - accuracy: 0.4630 - loss: 0.2154 - val_accuracy: 0.5600 - val_loss: 0.2050 - learning_rate: 1.0000e-04
# Epoch 21/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.4888 - loss: 0.2032
# Epoch 21: val_loss improved from 0.20499 to 0.20259, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 58s 394ms/step - accuracy: 0.4888 - loss: 0.2032 - val_accuracy: 0.5000 - val_loss: 0.2026 - learning_rate: 1.0000e-04
# Epoch 22/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.5151 - loss: 0.1990
# Epoch 22: val_loss did not improve from 0.20259
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 57s 225ms/step - accuracy: 0.5151 - loss: 0.1990 - val_accuracy: 0.5200 - val_loss: 0.2063 - learning_rate: 1.0000e-04
# Epoch 23/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.5382 - loss: 0.1901
# Epoch 23: val_loss did not improve from 0.20259
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 34s 229ms/step - accuracy: 0.5382 - loss: 0.1901 - val_accuracy: 0.4800 - val_loss: 0.2047 - learning_rate: 1.0000e-04
# Epoch 24/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.5418 - loss: 0.1833
# Epoch 24: val_loss improved from 0.20259 to 0.16857, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 60s 410ms/step - accuracy: 0.5418 - loss: 0.1833 - val_accuracy: 0.6200 - val_loss: 0.1686 - learning_rate: 1.0000e-04
# Epoch 25/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.5838 - loss: 0.1778
# Epoch 25: val_loss did not improve from 0.16857
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 35s 235ms/step - accuracy: 0.5838 - loss: 0.1778 - val_accuracy: 0.5400 - val_loss: 0.1706 - learning_rate: 1.0000e-04
# Epoch 26/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5936 - loss: 0.1682
# Epoch 26: val_loss did not improve from 0.16857
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 36s 244ms/step - accuracy: 0.5936 - loss: 0.1683 - val_accuracy: 0.5400 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 27/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6003 - loss: 0.1640
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 27: val_loss did not improve from 0.16857
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 38s 255ms/step - accuracy: 0.6003 - loss: 0.1640 - val_accuracy: 0.5600 - val_loss: 0.1763 - learning_rate: 1.0000e-04
# Epoch 28/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6503 - loss: 0.1523
# Epoch 28: val_loss improved from 0.16857 to 0.16591, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 56s 384ms/step - accuracy: 0.6502 - loss: 0.1523 - val_accuracy: 0.6400 - val_loss: 0.1659 - learning_rate: 1.0000e-05
# Epoch 29/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6518 - loss: 0.1527
# Epoch 29: val_loss improved from 0.16591 to 0.16393, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 59s 402ms/step - accuracy: 0.6518 - loss: 0.1527 - val_accuracy: 0.6000 - val_loss: 0.1639 - learning_rate: 1.0000e-05
# Epoch 30/30
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6799 - loss: 0.1443
# Epoch 30: val_loss improved from 0.16393 to 0.16201, saving model to cats.hdf5.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 51s 347ms/step - accuracy: 0.6797 - loss: 0.1444 - val_accuracy: 0.6000 - val_loss: 0.1620 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.

# %%
# summarize history for accuracy
plt.plot(hist_actividad_1.history['accuracy'])
plt.plot(hist_actividad_1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist_actividad_1.history['loss'])
plt.plot(hist_actividad_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Observemos las imágenes con Data Augmentation

plt.figure(figsize=(10,8))
batch = next(train_cat_aug)
#Plots our figures
for i in range(1,17):
  plt.subplot(4, 4, i)
  image_ = batch[0][i-1,:,:,:]
  plt.imshow(image_)
plt.show()

# %% [markdown]
# ## Segmentación con U-Net

# %%
# Obtenemos el conjunto de datos de entrenamiento y prueba
# !gdown 1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl -O stage1_test.zip
# !gdown 1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR -O stage1_train.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl
# To: /content/stage1_test.zip
# 100% 9.55M/9.55M [00:00<00:00, 120MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR
# From (redirected): https://drive.google.com/uc?id=1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR&confirm=t&uuid=b1a0c5b1-5217-424b-9d15-9977fefbb1eb
# To: /content/stage1_train.zip
# 100% 82.9M/82.9M [00:00<00:00, 198MB/s]

# %%
# Descomprimimos los conjuntos de datos.
# !unzip -q stage1_train.zip -d stage1_train/
# !unzip -q stage1_test.zip -d stage1_test/

# %%
IMG_WIDTH = 128 # Ancho en el que se redimensionarán las imágenes.
IMG_HEIGHT = 128 # Alto en el que se redimensionarán las imágenes.
IMG_CHANNELS = 3 # Canales de color que tienen las imágenes (rojo, verde y azul)
TRAIN_PATH = 'stage1_train/' # Ubicación del conjunto de datos de entrenamiento.
TEST_PATH = 'stage1_test/' # Ubicación del conjunto de datos de prueba.

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

# Establecemos una semilla para la generación de datos aleatorios
seed = 11
random.seed = seed
np.random.seed = seed

# %%
# Obtenemos los nombres de las imágenes de entrenamiento y prueba
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Redimensionamos todas las imágenes
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [04:10<00:00,  2.68it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:01<00:00, 52.74it/s]
# Done!

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (670, 128, 128, 3)
# (670, 128, 128, 1)

# %%
# Verificamos la imagen cruda y la máscara de segmentación de una imagen al azar.
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
# Out:
# <ipython-input-6-27e39e074f8a>:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(X_train[ix])
# <ipython-input-6-27e39e074f8a>:5: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(np.squeeze(Y_train[ix]))

# %% [markdown]
# U-Net es una arquitectura especializada para la segmentación de imágenes biomédicas https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/ .
#
# Esta arquitectura utiliza una serie de capas de convolución para realizar las predicciones y el esquema es el siguiente:
#
# ![U-Net Architecture](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
# Esta es la implementación en TensorFlow de U-Net

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s) # Capa convolucional
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.MeanIoU(2)])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 128, 128,  │          0 │ input_layer_1[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │        448 │ lambda_1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_19[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_9[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv2d_20[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │      4,640 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64, 64,    │          0 │ conv2d_21[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_10[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ conv2d_22[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 32, 32,    │          0 │ conv2d_23[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_11[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ conv2d_24[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │     73,856 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16, 16,    │          0 │ conv2d_25[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_12[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 128) │          0 │ conv2d_26[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 8, 8, 256) │          0 │ conv2d_27[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 16, 16,    │    131,200 │ conv2d_28[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 16, 16,    │          0 │ conv2d_29[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_14[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 32, 32,    │     32,832 │ conv2d_30[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 32, 32,    │          0 │ conv2d_31[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_15[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 64, 64,    │      8,224 │ conv2d_32[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 64, 64,    │          0 │ conv2d_33[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_16[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │      2,064 │ conv2d_34[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 128, 128,  │          0 │ conv2d_35[0][0]   │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_17[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │         17 │ conv2d_36[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,105 (7.40 MB)
#  Trainable params: 1,941,105 (7.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# La arquitectura cuenta con alrededor de 2 millones de parámetros que serán entrenados.

# %%
# Entrenamiento del modelo

earlystopper = EarlyStopping(patience=5, verbose=1)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50,
                    callbacks=[earlystopper])
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 571ms/step - loss: 0.5456 - mean_io_u_1: 0.3774 - val_loss: 0.3213 - val_mean_io_u_1: 0.3629
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 0.2752 - mean_io_u_1: 0.3810 - val_loss: 0.2956 - val_mean_io_u_1: 0.3629
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1959 - mean_io_u_1: 0.3718 - val_loss: 0.2181 - val_mean_io_u_1: 0.3629
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1684 - mean_io_u_1: 0.3742 - val_loss: 0.2111 - val_mean_io_u_1: 0.3629
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.1491 - mean_io_u_1: 0.3723 - val_loss: 0.2669 - val_mean_io_u_1: 0.3629
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1336 - mean_io_u_1: 0.3785 - val_loss: 0.1420 - val_mean_io_u_1: 0.3629
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.1462 - mean_io_u_1: 0.3734 - val_loss: 0.1421 - val_mean_io_u_1: 0.3629
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1373 - mean_io_u_1: 0.3815 - val_loss: 0.1358 - val_mean_io_u_1: 0.3629
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1128 - mean_io_u_1: 0.3805 - val_loss: 0.1529 - val_mean_io_u_1: 0.3629
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.1101 - mean_io_u_1: 0.3777 - val_loss: 0.1392 - val_mean_io_u_1: 0.3629
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.1063 - mean_io_u_1: 0.3804 - val_loss: 0.1306 - val_mean_io_u_1: 0.3629
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.1095 - mean_io_u_1: 0.3743 - val_loss: 0.1305 - val_mean_io_u_1: 0.3629
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1077 - mean_io_u_1: 0.3800 - val_loss: 0.1269 - val_mean_io_u_1: 0.3629
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1030 - mean_io_u_1: 0.3821 - val_loss: 0.1288 - val_mean_io_u_1: 0.3629
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1005 - mean_io_u_1: 0.3756 - val_loss: 0.1058 - val_mean_io_u_1: 0.3629
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0969 - mean_io_u_1: 0.3787 - val_loss: 0.1059 - val_mean_io_u_1: 0.3629
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0951 - mean_io_u_1: 0.3817 - val_loss: 0.1100 - val_mean_io_u_1: 0.3629
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0945 - mean_io_u_1: 0.3744 - val_loss: 0.1207 - val_mean_io_u_1: 0.3629
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0888 - mean_io_u_1: 0.3812 - val_loss: 0.1076 - val_mean_io_u_1: 0.3629
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0948 - mean_io_u_1: 0.3788 - val_loss: 0.1111 - val_mean_io_u_1: 0.3629
# Epoch 20: early stopping

# %%
# Predicción sobre los datos de entrenamiento, validación y prueba

preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]),
                                       (sizes_test[i][0], sizes_test[i][1]),
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de entrenamiento

ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# <ipython-input-14-02c251d7894d>:4: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(X_train[ix])
# <ipython-input-14-02c251d7894d>:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(np.squeeze(Y_train[ix]))
# <ipython-input-14-02c251d7894d>:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(np.squeeze(preds_train_t[ix]))

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de validación

ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()
# Out:
# <ipython-input-15-65d314a78000>:4: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(X_train[int(X_train.shape[0]*0.9):][ix])
# <ipython-input-15-65d314a78000>:6: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
# <ipython-input-15-65d314a78000>:8: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(np.squeeze(preds_val_t[ix]))

# %% [markdown]
# ## Actividad 2
#
# Visualiza la salida de la según fase de convoluciones en downscaling (c2) y la penúltima capa de upscaling (c8). Puedes utilizar las funciones de la clase anterior.

# %%
# Prográmame!
def get_activations(model,img_array):
  if img_array.ndim == 3:
    img_array = np.expand_dims(img_array, axis=0)

  # Creamos un modelo que entrega los resultados después de cada capa
  layer_outputs = [layer.output for layer in model.layers]
  layer_names = [layer.name for layer in model.layers]
  activation_model = tf.keras.models.Model(inputs=model.input, outputs=layer_outputs)
  activations = activation_model.predict(img_array)
  activations = list(zip(layer_names,activations))
  return activations

def plot_conv_layer_result(activations,j):
  fig, axs = plt.subplots(
      nrows=2,
      ncols=8,
      figsize=(15,8)
  )
  fig.suptitle(activations[j][0])
  for i,ax in enumerate(axs.ravel()):
      ax.imshow(activations[j][1][0,:,:,i], cmap="viridis")
      ax.axis("off")
  plt.show()

# %%
img = X_train[0]
activations = get_activations(model, img)
plot_conv_layer_result(activations, 8)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
plot_conv_layer_result(activations, 36)
